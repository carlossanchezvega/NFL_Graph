# %%
import networkx as nx
import toolz
import json
from itertools import chain
from operator import itemgetter

# %%
#we load the data.
with open('/home/csanchez/Downloads/MongoDB-Neo4J-ElasticSearch-Assigment-master/GrahpAnalysis/nflresults.json', 'r',errors='ignore') as nfl:
    results = json.load(nfl)
print(results[:1])
# Out:
# [[{'yearsPro': 1, 'profileUrl': 'http://www.nfl.com/player/elijhaapenny/2556762/profile', 'team': 'ARI', 'height': 73, 'birthDate': '8/17/1993', 'uniformNumber': 35, 'gsisName': '', 'weight': 234, 'lastName': 'Penny', 'position': 'RB', 'college': 'Idaho', 'profileId': 2556762, 'status': 'Active', 'firstName': 'Elijhaa', 'playerId': '00-0032813', 'fullName': 'Elijhaa Penny'}, {'yearsPro': 3, 'profileUrl': 'http://www.nfl.com/player/davidjohnson/2553435/profile', 'team': 'ARI', 'height': 73, 'birthDate': '12/16/1991', 'uniformNumber': 31, 'gsisName': '', 'weight': 224, 'lastName': 'Johnson', 'position': 'RB', 'college': 'Northern Iowa', 'profileId': 2553435, 'status': 'InjuredReserve', 'firstName': 'David', 'playerId': '00-0032187', 'fullName': 'David Johnson'}, {'yearsPro': 8, 'profileUrl': 'http://www.nfl.com/player/mikeiupati/497016/profile', 'team': 'ARI', 'height': 77, 'birthDate': '5/12/1987', 'uniformNumber': 76, 'gsisName': 'M.Iupati', 'weight': 331, 'lastName': 'Iupati', 'position': 'OG', 'college': 'Idaho', 'profileId': 497016, 'status': 'InjuredReserve', 'firstName': 'Mike', 'playerId': '00-0027869', 'fullName': 'Mike Iupati'}, {'yearsPro': 8, 'profileUrl': 'http://www.nfl.com/player/jaredveldheer/497061/profile', 'team': 'ARI', 'height': 80, 'birthDate': '6/14/1987', 'uniformNumber': 68, 'gsisName': 'J.Veldheer', 'weight': 321, 'lastName': 'Veldheer', 'position': 'OT', 'college': 'Hillsdale', 'profileId': 497061, 'status': 'InjuredReserve', 'firstName': 'Jared', 'playerId': '00-0027674', 'fullName': 'Jared Veldheer'}, {'yearsPro': 2, 'profileUrl': 'http://www.nfl.com/player/evanboehm/2555181/profile', 'team': 'ARI', 'height': 75, 'birthDate': '8/19/1993', 'uniformNumber': 70, 'gsisName': '', 'weight': 310, 'lastName': 'Boehm', 'position': 'OG', 'college': 'Missouri', 'profileId': 2555181, 'status': 'Active', 'firstName': 'Evan', 'playerId': '00-0032777', 'fullName': 'Evan Boehm'}, {'yearsPro': 4, 'profileUrl': 'http://www.nfl.com/player/brittangolden/2535988/profile', 'team': 'ARI', 'height': 71, 'birthDate': '7/20/1988', 'uniformNumber': 10, 'gsisName': 'B.Golden', 'weight': 186, 'lastName': 'Golden', 'position': 'WR', 'college': 'West Texas A&M', 'profileId': 2535988, 'status': 'InjuredReserve', 'firstName': 'Brittan', 'playerId': '00-0029336', 'fullName': 'Brittan Golden'}, {'profileUrl': 'http://www.nfl.com/player/rickyseals-jones/2559248/profile', 'team': 'ARI', 'height': 77, 'birthDate': '3/15/1995', 'uniformNumber': 86, 'gsisName': '', 'weight': 243, 'lastName': 'Seals-Jones', 'position': 'TE', 'college': 'Texas A&M', 'profileId': 2559248, 'status': 'Active', 'firstName': 'Ricky', 'playerId': '00-0033611', 'fullName': 'Ricky Seals-Jones'}, {'yearsPro': 19, 'profileUrl': 'http://www.nfl.com/player/phildawson/2500351/profile', 'team': 'ARI', 'height': 71, 'birthDate': '1/23/1975', 'uniformNumber': 4, 'gsisName': 'P.Dawson', 'weight': 200, 'lastName': 'Dawson', 'position': 'K', 'college': 'Texas', 'profileId': 2500351, 'status': 'Active', 'firstName': 'Phil', 'playerId': '00-0004091', 'fullName': 'Phil Dawson'}, {'yearsPro': 1, 'profileUrl': 'http://www.nfl.com/player/bronsonhill/2554357/profile', 'team': 'ARI', 'height': 70, 'birthDate': '1/2/1993', 'uniformNumber': 48, 'gsisName': '', 'weight': 215, 'lastName': 'Hill', 'position': 'RB', 'college': 'Eastern Michigan', 'profileId': 2554357, 'status': 'Active', 'firstName': 'Bronson', 'playerId': '00-0032298', 'fullName': 'Bronson Hill'}, {'yearsPro': 10, 'profileUrl': 'http://www.nfl.com/player/tyvonbranch/1681/profile', 'team': 'ARI', 'height': 72, 'birthDate': '12/11/1986', 'uniformNumber': 27, 'gsisName': 'T.Branch', 'weight': 210, 'lastName': 'Branch', 'position': 'SS', 'college': 'Connecticut', 'profileId': 1681, 'status': 'InjuredReserve', 'firstName': 'Tyvon', 'playerId': '00-0026240', 'fullName': 'Tyvon Branch'}, {'yearsPro': 4, 'profileUrl': 'http://www.nfl.com/player/deonebucannon/2543769/profile', 'team': 'ARI', 'height': 73, 'birthDate': '8/30/1992',  ...

# %%
#we create a list of tuples with the edges of our graph, NFL team,
#and College. Looking at the team players, we are going to sort 
#the different origin of the players of every team.
teams=list(chain.from_iterable(results))

teams_hash=toolz.groupby('team', teams)
graph_results=[]
for key, team in teams_hash.items():
    team_name = key
    college_unique=set()
    for college in team:
        if college['college'] not in college_unique:
            graph_results.append(tuple([team_name,college['college']]))
        else:
            college_unique.add(college['college'])
print(graph_results)
# Out:
# [('MIN', 'Notre Dame'), ('MIN', 'Texas'), ('MIN', 'Texas-San Antonio'), ('MIN', 'Michigan State'), ('MIN', 'UCLA'), ('MIN', 'Northern Colorado'), ('MIN', 'Kansas State'), ('MIN', 'Iowa'), ('MIN', 'Houston'), ('MIN', 'Nebraska'), ('MIN', 'Notre Dame'), ('MIN', 'San Diego State'), ('MIN', 'Minnesota State'), ('MIN', 'Connecticut'), ('MIN', 'Cincinnati'), ('MIN', 'Notre Dame'), ('MIN', 'Washington'), ('MIN', 'Michigan Tech'), ('MIN', 'Oklahoma'), ('MIN', 'Clemson'), ('MIN', 'UCLA'), ('MIN', 'Missouri'), ('MIN', 'Boston College'), ('MIN', 'Oregon State'), ('MIN', 'Vanderbilt'), ('MIN', 'Augustana (S.D.)'), ('MIN', 'Rice'), ('MIN', 'Florida State'), ('MIN', 'Portland State'), ('MIN', 'USC'), ('MIN', 'Mississippi'), ('MIN', 'Georgia Southern'), ('MIN', 'Harvard'), ('MIN', 'Iowa'), ('MIN', 'Michigan'), ('MIN', 'Minnesota'), ('MIN', 'Miami (Fla.)'), ('MIN', 'Miami (Fla.)'), ('MIN', 'Kansas State'), ('MIN', 'Texas A&M'), ('MIN', 'East Carolina'), ('MIN', 'Ohio State'), ('MIN', 'Southern Mississippi'), ('MIN', 'Southern Mississippi'), ('MIN', 'Oklahoma'), ('MIN', 'Clemson'), ('MIN', 'UCLA'), ('MIN', 'Florida'), ('MIN', 'Arkansas'), ('MIN', 'Louisville'), ('MIN', 'Central Florida'), ('MIN', 'Belhaven College'), ('MIN', 'Maryland'), ('MIN', 'Texas Christian'), ('MIN', 'LSU'), ('MIN', 'Florida State'), ('MIN', 'LSU'), ('MIN', 'UCLA'), ('MIN', 'Virginia'), ('DET', 'Texas Tech'), ('DET', 'Rutgers'), ('DET', 'Notre Dame'), ('DET', 'Arkansas'), ('DET', 'Wofford'), ('DET', 'Michigan'), ('DET', 'Central Michigan'), ('DET', 'Nebraska'), ('DET', 'Illinois'), ('DET', 'Eastern Oregon'), ('DET', 'Utah State'), ('DET', 'Eastern Michigan'), ('DET', 'Brigham Young'), ('DET', 'Cincinnati'), ('DET', 'Notre Dame'), ('DET', 'Washington'), ('DET', 'Penn State'), ('DET', 'Louisiana-Lafayette'), ('DET', 'Michigan'), ('DET', 'Southern Utah'), ('DET', 'Pennsylvania'), ('DET', 'Northern Illinois'), ('DET', 'Alabama'), ('DET', 'Wisconsin'), ('DET', 'Auburn'), ('DET', 'North Carolina'), ('DET', 'California-Irvine'), ('DET', 'Florida'), ('DET', 'Tennessee'), ('DET', 'Toledo'), ('DET', 'Appalachian State'), ('DET', 'San Diego'), ('DET', 'Toledo'), ('DET', 'Washington State'), ('DET', 'Boston College'), ('DET', 'Notre Dame'), ('DET', 'Oregon'), ('DET', 'Syracuse'), ('DET', 'Delaware'), ('DET', 'Arkansas'), ('DET', 'Jacksonville'), ('DET', 'Akron'), ('DET', 'Central Florida'), ('DET', 'West Virginia'), ('DET', 'Illinois'), ('DET', 'Georgia'), ('DET', 'Georgia'), ('DET', 'California'), ('DET', 'Fresno State'), ('DET', 'New Mexico'), ('DET', 'Mississippi State'), ('DET', 'Monmouth (N.J.)'), ('DET', 'North Carolina'), ('DET', 'South Carolina'), ('DET', 'Boston College'), ('DET', 'Norfolk State'), ('DET', 'Texas'), ('DET', 'Ohio State'), ('DET', 'Miami (Fla.)'), ('DET', 'Texas Tech'), ('DET', 'South Dakota'), ('DET', 'Wake Forest'), ('DET', 'Temple'), ('DET', 'Texas A&M'), ('DET', 'Houston'), ('DET', 'Florida'), ('DET', 'Penn State'), ('CIN', 'Wyoming'), ('CIN', 'Pittsburgh'), ('CIN', 'Illinois'), ('CIN', 'Alabama'), ('CIN', 'Texas'), ('CIN', 'Rutgers'), ('CIN', 'Duke'), ('CIN', 'Colorado'), ('CIN', 'Texas A&M'), ('CIN', 'Rutgers'), ('CIN', 'Texas-San Antonio'), ('CIN', 'South Carolina'), ('CIN', 'Washington'), ('CIN', 'Auburn'), ('CIN', 'Texas A&M'), ('CIN', 'Georgia'), ('CIN', 'North Carolina'), ('CIN', 'LSU'), ('CIN', 'USC'), ('CIN', 'Louisiana Tech'), ('CIN', 'Arkansas'), ('CIN', 'Michigan State'), ('CIN', 'LSU'), ('CIN', 'Notre Dame'), ('CIN', 'Alabama'), ('CIN', 'Boise State'), ('CIN', 'Tennessee'), ('CIN', 'Illinois'), ('CIN', 'Arizona State'), ('CIN', 'Michigan'), ('CIN', 'Florida'), ('CIN', 'Notre Dame'), ('CIN', 'LSU'), ('CIN', 'Alabama'), ('CIN', 'West Virginia'), ('CIN', 'Oklahoma'), ('CIN', 'Texas Christian'), ('CIN', 'Virginia'), ('CIN', 'Miami (Fla.)'), ('CIN', 'North Carolina A&T'), ('CIN', 'Auburn'), ('CIN', 'Georgia Tech'), ('CIN', 'UCLA'), ('CIN', 'Wisconsin'), ('CIN', 'Georgia'), ('CIN', 'Texas'), ('CIN', 'Stanford'), ('CIN', 'Auburn'), ('CIN', 'Penn St ...

# %%
#we create our graph.
NFLGraph = nx.Graph()
NFLGraph.add_edges_from(graph_results)
print(nx.info(Graph))
# Out:
# Name:
# Type: Graph
# Number of nodes: 306
# Number of edges: 1554
# Average degree:  10.1569

# %%
#Degress of Centrality.
results= sorted(nx.degree_centrality(G=NFLGraph).items(),key=itemgetter(1),
             reverse=True)

#Teams with most heterogenous players origin.
teams_centrality = [register for register in results if len(register[0])<=3]
print(teams_centrality[:5])
#SF Giants , Washington Redkings and Detroit Lions.

#Colleges that provide players to more teams.
teams_centrality = [register for register in results if len(register[0])>3]
print(teams_centrality[:5])
#Florida, Ohio State and Miami.
# Out:
# [('SF', 0.18032786885245902), ('WAS', 0.18032786885245902), ('DET', 0.18032786885245902), ('NYJ', 0.17704918032786884), ('SEA', 0.17704918032786884)]
# [('Florida', 0.08852459016393442), ('Ohio State', 0.08196721311475409), ('Miami (Fla.)', 0.07868852459016393), ('Alabama', 0.07868852459016393), ('Michigan', 0.06885245901639345)]

# %%
#Betweness.
results = sorted(nx.betweenness_centrality(G=NFLGraph).items(),key=itemgetter(1),
             reverse=True)

#Teams with best connected  with different  colleges origin.
teams_betweness = [register for register in results if len(register[0])<=3]
print(teams_betweness[:5])

#Best connected colleges with teams.
college_betweness = [register for register in results if len(register[0])>3]
print(college_betweness[:5])
# Out:
# [('IND', 0.07351727630348392), ('NYJ', 0.0707289434377185), ('NYG', 0.06151476872598788), ('ARI', 0.06020776597717756), ('TB', 0.05954842938138588)]
# [('Florida', 0.027593951691461494), ('Ohio State', 0.023360924788243437), ('Miami (Fla.)', 0.019852553139296087), ('Alabama', 0.019600859491233122), ('Penn State', 0.015617110650877964)]

# %%
#Clossness.
results= sorted(nx.closeness_centrality(G=NFLGraph).items(),key=itemgetter(1),
             reverse=True)

#Teams with the nearest connection to the different colleges.
teams_clossness = [register for register in results if len(register[0])<=3]
print(teams_clossness[:5])

#Colleges with the nearest connection to all the teams.
colleges_clossness = [register for register in results if len(register[0])>3]
print(colleges_clossness[:5])
# Out:
# [('LSU', 0.4895666131621188), ('USC', 0.48183254344391785), ('SF', 0.3935483870967742), ('WAS', 0.3935483870967742), ('DET', 0.3935483870967742)]
# [('Florida', 0.5041322314049587), ('Ohio State', 0.49114331723027377), ('Miami (Fla.)', 0.47433903576982894), ('Alabama', 0.4728682170542636), ('Texas', 0.4572713643178411)]

# %%
#we save the graph.
nx.write_gpickle(NFLGraph,'nflgraph.gpickle.1')
